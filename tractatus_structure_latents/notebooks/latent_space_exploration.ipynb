# %% [markdown]
# # Latent Space Exploration
#
# Use `evaluation.evaluate_structure --export-latents` first, then load the exported tensor here for custom analyses.

# %%
import json
from pathlib import Path
import torch

z = torch.load(Path('../../runs/tractatus_latents.pt'), map_location='cpu')
rows = json.loads(Path('../data/tractatus.json').read_text())
z.shape, rows[0]['id']
